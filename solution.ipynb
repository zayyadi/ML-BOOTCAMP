# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("downloaded_file.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.isna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
a = df.isna()

if a is True:
    print(a)
else:
    print("None")
# Out:
# None

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
houses_near_bay = df[df['ocean_proximity'] == 'NEAR BAY']
houses_near_bay
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 19067    -122.45     38.28                20.0       3306.0           503.0
# 19068    -122.47     38.29                14.0       3732.0           846.0
# 19069    -122.45     38.27                25.0       5024.0           881.0
# 19077    -122.49     38.27                 8.0       5092.0           988.0
# 19104    -122.51     38.17                 8.0       5875.0          1115.0
#
# ...

# %%
average_median_house_value_near_bay = houses_near_bay['median_house_value'].mean()

# Print the result
print("Average 'median_house_value' for houses near the bay:", average_median_house_value_near_bay)
# Out:
# Average 'median_house_value' for houses near the bay: 259212.31179039303

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
mean_total_bedroom = df['total_bedrooms'].mean()
print(f"mean before filling NA: {mean_total_bedroom}")
df['total_bedrooms'].fillna(mean_total_bedroom, inplace=True)
print(f"mean after filling: {df['total_bedrooms'].mean()}")
# Out:
# mean before filling NA: 537.8705525375617
# mean after filling: 537.8705525375617

# %%
island_df = df[df['ocean_proximity'] == 'ISLAND']
selected_columns = island_df[['housing_median_age', 'total_rooms', 'total_bedrooms']]

# %%
X = selected_columns.to_numpy()

# %%
XTX = X.T @ X

# %%
XTX_inverse = np.linalg.inv(XTX)

# %%
y = np.array([950, 1300, 800, 1000, 1300])

# %%
w = XTX_inverse @ X.T @ y

# %%
last_element_of_w = w[-1]

# %%
last_element_of_w
# Out:
# 5.699229455065586
